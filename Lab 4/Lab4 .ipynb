# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %% [markdown]
# ---

# %% [markdown]
# # 1. Load Dataset

# %%
pd.set_option("display.max_columns", None)

df = pd.read_csv("Sport_car_price.csv")
df.head(10)
# Out:
#         Car Make             Car Model  Year Engine Size (L) Horsepower  \
# 0        Porsche                   911  2022               3        379
# 1    Lamborghini               Huracan  2021             5.2        630
# 2        Ferrari               488 GTB  2022             3.9        661
# 3           Audi                    R8  2022             5.2        562
# 4        McLaren                  720S  2021               4        710
# 5            BMW                    M8  2022             4.4        617
# 6  Mercedes-Benz                AMG GT  2021               4        523
# 7      Chevrolet              Corvette  2021             6.2        490
# 8           Ford  Mustang Shelby GT500  2022             5.2        760
# 9         Nissan            GT-R Nismo  2021             3.8        600
#
#   Torque (lb-ft) 0-60 MPH Time (seconds) Price (in USD)
# 0            331                       4        101,200
# 1            443                     2.8        274,390
# 2            561                       3        333,750
# 3            406                     3.2        142,700
# 4            568                     2.7        298,000
# 5            553                     3.1        130,000
# 6            494                     3.8        118,500
# 7            465                     2.8         59,900
# 8            625                     3.5         81,000
# 9            481                     2.5        212,000

# %%
cols_to_fix = ['Horsepower', 'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)', 'Engine Size (L)']

for col in cols_to_fix:
    df.loc[:, col] = pd.to_numeric(df[col].astype(str).str.replace(r'[$,+]', '', regex=True).str.replace(',', ''), errors='coerce')

numeric_c = df.select_dtypes(include=np.number).columns
print("Updated numeric columns:", numeric_c.tolist())
# Out:
# Updated numeric columns: ['Year', 'Engine Size (L)', 'Horsepower', 'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)']

# %% [markdown]
# ## 2. Data Quality Assessment
# ### 2.1 Check Data Types

# %%
df.dtypes
# Out:
# Car Make                       str
# Car Model                      str
# Year                         int64
# Engine Size (L)            float64
# Horsepower                   int64
# Torque (lb-ft)             float64
# 0-60 MPH Time (seconds)    float64
# Price (in USD)               int64
# dtype: object

# %%
df.shape
# Out:
# (1007, 8)

# %% [markdown]
# ### 2.2 Convert Incorrect Data Types

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Car Make                 1007 non-null   str
#  1   Car Model                1007 non-null   str
#  2   Year                     1007 non-null   int64
#  3   Engine Size (L)          948 non-null    float64
#  4   Horsepower               1007 non-null   int64
#  5   Torque (lb-ft)           1003 non-null   float64
#  6   0-60 MPH Time (seconds)  1006 non-null   float64
#  7   Price (in USD)           1007 non-null   int64
# dtypes: float64(3), int64(3), str(2)
# memory usage: 63.1 KB

# %%
df.describe()
# Out:
#               Year  Engine Size (L)    Horsepower  Torque (lb-ft)  \
# count  1007.000000       948.000000   1007.000000     1003.000000
# mean   2021.201589         4.395781    657.984111      559.570289
# std       2.019802         1.398801    593.017842      441.380051
# min    1965.000000         0.000000    181.000000        0.000000
# 25%    2021.000000         3.500000    454.000000      406.000000
# 50%    2021.000000         4.000000    591.000000      509.000000
# 75%    2022.000000         5.200000    708.500000      604.000000
# max    2023.000000         8.400000  10000.000000    10000.000000
#
#        0-60 MPH Time (seconds)  Price (in USD)
# count              1006.000000    1.007000e+03
# mean                  3.515010    3.820359e+05
# std                   0.776358    7.383227e+05
# min                   1.800000    2.500000e+04
# 25%                   2.900000    7.180000e+04
# 50%                   3.500000    1.400000e+05
# 75%                   4.000000    2.500000e+05
# max                   6.500000    5.200000e+06

# %%
df.isnull().sum()
# Out:
# Car Make                    0
# Car Model                   0
# Year                        0
# Engine Size (L)            59
# Horsepower                  0
# Torque (lb-ft)              4
# 0-60 MPH Time (seconds)     1
# Price (in USD)              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(292)

# %% [markdown]
# # 3. Handling Missing Values

# %%
numeric_c = df.select_dtypes(include=np.number).columns
df[numeric_c] = df[numeric_c].fillna(df[numeric_c].median())
# Out:
#       Year  Engine Size (L)  Horsepower  Torque (lb-ft)  \
# 0     2022              3.0         379           331.0
# 1     2021              5.2         630           443.0
# 2     2022              3.9         661           561.0
# 3     2022              5.2         562           406.0
# 4     2021              4.0         710           568.0
# ...    ...              ...         ...             ...
# 1002  2022              5.0        1280          1106.0
# 1003  2021              4.0        1972          1254.0
# 1004  2021              4.0         789           590.0
# 1005  2021              6.0         764           738.0
# 1006  2021              4.0        1888          1696.0
#
#       0-60 MPH Time (seconds)  Price (in USD)
# 0                        4.00          101200
# 1                        2.80          274390
# 2                        3.00          333750
# 3                        3.20          142700
# 4                        2.70          298000
# ...                       ...             ...
# 1002                     2.50         3000000
# 1003                     2.00         2000000
# 1004                     2.70         1000000
# 1005                     3.00         2600000
# 1006                     1.85         2400000
#
# [1007 rows x 6 columns]

# %%
print(f"Remaining missing values : {df.isnull().sum().sum() }")
# Out:
# Remainig missing values : 64

# %% [markdown]
# # 4. Handling Outliers

# %%
plt.figure(figsize=(12,6))
df[numeric_c].boxplot(rot=45)
plt.title("Boxplot Before Removing Outliers")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.figure(figsize=(12,6))
#       2 df[numeric_c].boxplot(rot=45)
#       3 plt.title("Boxplot Before Removing Outliers")
#
# NameError: name 'plt' is not defined

# %%
Q1 = df['Price (in USD)'].quantile(0.25)
Q3 = df['Price (in USD)'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR 

df_no_outliers = df[(df['Price (in USD)'] >= lower_bound) & (df['Price (in USD)'] <= upper_bound)].copy()

print(f"Original shape: {df.shape}")
print(f"Shape after removing price outliers: {df_no_outliers.shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Q1 = df['Price (in USD)'].quantile(0.25)
#       2 Q3 = df['Price (in USD)'].quantile(0.75)
#       3 IQR = Q3 - Q1
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(12,6))
df_no_outliers[numeric_c].boxplot(rot=45)
plt.title("Boxplot After Removing Outliers")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.figure(figsize=(12,6))
#       2 df_no_outliers[numeric_c].boxplot(rot=45)
#       3 plt.title("Boxplot After Removing Outliers")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # 5. Data Transformation - Normalization

# %%
pca_features = ['Horsepower', 'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)']
df_no_outliers = df_no_outliers.dropna(subset=pca_features)

print(f"Dataset is now 100% clean for PCA. Rows remaining: {len(df_no_outliers)}")
# Out:
# Dataset is now 100% clean for PCA. Rows remaining: 884

# %% [markdown]
# ### Min-Max Scaling

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA

pca_features = ['Horsepower', 'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)']
df_no_outliers = df_no_outliers.dropna(subset=pca_features)

data_to_scale = df_no_outliers[pca_features]


minmax_scaler = MinMaxScaler()
df_minmax = pd.DataFrame(minmax_scaler.fit_transform(data_to_scale), columns=pca_features)

print("Min-Max Normalized Data (First 5 rows):")
df_minmax.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 from sklearn.decomposition import PCA
#       4 pca_features = ['Horsepower', 'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)']
# ----> 5 df_no_outliers = df_no_outliers.dropna(subset=pca_features)
#       7 data_to_scale = df_no_outliers[pca_features]
#      10 minmax_scaler = MinMaxScaler()
#
# NameError: name 'df_no_outliers' is not defined

# %% [markdown]
# ### Z-Score Normalization

# %%
features_to_check = ['Horsepower', 'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)']
std_scaler = StandardScaler()
df_zscore_scaled = std_scaler.fit_transform(df_no_outliers[features_to_check])


df_zscore = pd.DataFrame(df_zscore_scaled, columns=features_to_check)

print("Z-Score Normalized Data (First 5 rows):")
df_zscore.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 features_to_check = ['Horsepower', 'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)']
#       2 std_scaler = StandardScaler()
# ----> 3 df_zscore_scaled = std_scaler.fit_transform(df_no_outliers[pca_features])
#       6 df_zscore = pd.DataFrame(df_zscore_scaled, columns=pca_features)
#       8 print("Z-Score Normalized Data (First 5 rows):")
#
# NameError: name 'pca_features' is not defined

# %% [markdown]
# # 6. Data Reduction - PCA

# %% [markdown]
# ### Correlation before PCA

# %%
correlation_features = ['Horsepower', 'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)']
corr_matrix = df_no_outliers[correlation_features].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Matrix of Performance Features")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 correlation_features = ['Horsepower', 'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)']
# ----> 2 corr_matrix = df_no_outliers[correlation_features].corr()
#       4 plt.figure(figsize=(10, 8))
#       5 sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
#
# NameError: name 'df_no_outliers' is not defined

# %%
pca = PCA()
pca_results = pca.fit_transform(df_zscore_scaled)
explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio by Each Principal Component:")
for i, ratio in enumerate(explained_variance):
    print(f"Principal Component {i+1}: ({ratio*100:.2f})%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 pca = PCA()
# ----> 2 pca_results = pca.fit_transform(df_zscore_scaled)
#       3 explained_variance = pca.explained_variance_ratio_
#       4 print("Explained Variance Ratio by Each Principal Component:")
#
# NameError: name 'df_zscore_scaled' is not defined

# %%
plt.figure(figsize=(8, 5))
plt.bar(range(1, len(explained_variance) + 1), explained_variance, alpha=0.7, label='Individual Variance')
plt.step(range(1, len(explained_variance) + 1), np.cumsum(explained_variance), where='mid', label='Cumulative Variance', color='red')

plt.title("PCA Explained Variance (Scree Plot)")
plt.xlabel("Principal Components")
plt.ylabel("Variance Explained Ratio")
plt.legend(loc='best')
plt.grid(axis='y', linestyle='--')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 plt.figure(figsize=(8, 5))
# ----> 2 plt.bar(range(1, len(explained_variance) + 1), explained_variance, alpha=0.7, label='Individual Variance')
#       3 plt.step(range(1, len(explained_variance) + 1), np.cumsum(explained_variance), where='mid', label='Cumulative Variance', color='red')
#       5 plt.title("PCA Explained Variance (Scree Plot)")
#
# NameError: name 'explained_variance' is not defined
